# %% [markdown]
# # Tutorial 5 - Particle Morphologies

# %% [markdown]
# It is sometimes useful to use surface energies in order to generate particle morphologies. This tutorial demonstrates how to obtain surface energies for surfaces containing adsorbed species using surfinpy and how to use these surface energies to generate a wulff construction using pymatgen(1)
#
#
#
# (1) https://www.sciencedirect.com/science/article/pii/S0927025612006295?via%3Dihub

# %%
import numpy as np

from surfinpy import p_vs_t as pt
from surfinpy import wulff  
from pymatgen.core.surface import SlabGenerator, generate_all_slabs, Structure, Lattice
from pymatgen.analysis.wulff import WulffShape

# %%
adsorbant = -21.55846785
SE = 1.44
stoich = {'M': 24, 'X': 48, 'Y': 0, 'Area':60.22, 'Energy': -575.66, 'Label': 'Stoich'}
Adsorbant_1 = {'M': 24, 'X': 48, 'Y': 2, 'Area': 60.22, 'Energy': -622.87,  'Label': '1 Species'}
Adsorbant_2 = {'M': 24, 'X': 48, 'Y': 4, 'Area': 60.22, 'Energy': -672.22, 'Label': '2 Species'}

data = [Adsorbant_1, Adsorbant_2]
coverage = np.array([(1.66 * 10**18), (3.32 * 10**18)])
thermochem = np.genfromtxt('Free_energy.txt', dtype=float)

Surface_100 = wulff.calculate_surface_energy(stoich, data, SE, adsorbant, coverage, thermochem, 298, 0)

# %%
adsorbant = -21.55846785
SE = 1.06

stoich = {'M': 24, 'X': 48, 'Y': 0, 'Area': 85.12, 'Energy': -672.95, 'Label': 'Stoich'}
Adsorbant_1 = {'M': 24, 'X': 48, 'Y': 2, 'Area': 85.12, 'Energy': -718.62,  'Label': '1 Species'}
Adsorbant_2 = {'M': 24, 'X': 48, 'Y': 4, 'Area':85.12, 'Energy': -766.80, 'Label': '2 Species'}

data = [Adsorbant_1, Adsorbant_2]
coverage = np.array([(1.17 * 10**18), (2.35 * 10**18)])
thermochem = np.genfromtxt('Free_energy.txt', dtype=float)
Surface_110 = wulff.calculate_surface_energy(stoich, data, SE, adsorbant, coverage, thermochem, 298, 0)

# %%
adsorbant = -21.55846785
SE = 0.76
stoich = {'M': 24, 'X': 48, 'Y': 0, 'Area': 77.14, 'Energy': -579.610371, 'Label': '0.00 - $Ce^{4+}$'}
Adsorbant_1 = {'M': 24, 'X': 48, 'Y': 2, 'Area': 77.14, 'Energy': -624.24728,  'Label': '1.66 - $Ce^{4+}$'}
Adsorbant_2 = {'M': 24, 'X': 48, 'Y': 4, 'Area': 77.14, 'Energy': -670.77988, 'Label': '3.32 - $Ce^{4+}$'}

data = [Adsorbant_1, Adsorbant_2]
coverage = np.array([(1.30 * 10**18), (2.59 * 10**18)])
thermochem = np.genfromtxt('Free_energy.txt', dtype=float)

Surface_111 = wulff.calculate_surface_energy(stoich, data, SE, adsorbant, coverage, thermochem, 298, 0)

# %%
print(Surface_100)
print(Surface_110)
print(Surface_111)
# Out:
# [ 1.44        1.07103403  0.41749043]
# [ 1.06        0.94428527  0.59132136]
# [ 0.76        0.73901533  0.52153199]

# %%
lattice = Lattice.cubic(5.411)
ceo = Structure(lattice,["Ce", "O"],
               [[0,0,0], [0.25,0.25,0.25]])
surface_energies_ceo = {(1,1,1): Surface_111[0], (1,1,0): Surface_110[0], (1,0,0): Surface_100[0]}

miller_list = surface_energies_ceo.keys()
e_surf_list = surface_energies_ceo.values()

# We can now construct a Wulff shape with an accuracy up to a max Miller index of 3
wulffshape = WulffShape(ceo.lattice, miller_list, e_surf_list)

# Let's get some useful information from our wulffshape object
print("shape factor: %.3f, anisotropy: \
# %.3f, weighted surface energy: %.3f J/m^2" %(wulffshape.shape_factor, 
                                       wulffshape.anisotropy,
                                       wulffshape.weighted_surface_energy))


# If we want to see what our Wulff shape looks like
wulffshape.show(custom_colors={(1, 1, 1): [0.40392156862745099, 0.0, 0.12156862745098039, 1.0]}, direction=(1.00, 0.25, 0.25), output="Bare.png")
# Out:
# shape factor: 5.719, anisotropy: 0.000, weighted surface energy: 0.760 J/m^2

# %%
lattice = Lattice.cubic(5.411)
ceo = Structure(lattice,["Ce", "O"],
               [[0,0,0], [0.25,0.25,0.25]])
surface_energies_ceo = {(1,1,1): Surface_111[1], (1,1,0): Surface_110[1], (1,0,0): Surface_100[1]}

miller_list = surface_energies_ceo.keys()
e_surf_list = surface_energies_ceo.values()

# We can now construct a Wulff shape with an accuracy up to a max Miller index of 3
wulffshape = WulffShape(ceo.lattice, miller_list, e_surf_list)

# Let's get some useful information from our wulffshape object
print("shape factor: %.3f, anisotropy: \
# %.3f, weighted surface energy: %.3f J/m^2" %(wulffshape.shape_factor, 
                                       wulffshape.anisotropy,
                                       wulffshape.weighted_surface_energy))


# If we want to see what our Wulff shape looks like
wulffshape.show(color_set="RdBu", direction=(1.00, 0.25, 0.25), output="One_Species.png")
# Out:
# shape factor: 5.574, anisotropy: 0.094, weighted surface energy: 0.755 J/m^2

# %%
lattice = Lattice.cubic(5.411)
ceo = Structure(lattice,["Ce", "O"],
               [[0,0,0], [0.25,0.25,0.25]])
surface_energies_ceo = {(1,1,1): Surface_111[2], (1,1,0): Surface_110[2], (1,0,0): Surface_100[2]}

miller_list = surface_energies_ceo.keys()
e_surf_list = surface_energies_ceo.values()

# We can now construct a Wulff shape with an accuracy up to a max Miller index of 3
wulffshape = WulffShape(ceo.lattice, miller_list, e_surf_list)

# Let's get some useful information from our wulffshape object
print("shape factor: %.3f, anisotropy: \
# %.3f, weighted surface energy: %.3f J/m^2" %(wulffshape.shape_factor, 
                                       wulffshape.anisotropy,
                                       wulffshape.weighted_surface_energy))


# If we want to see what our Wulff shape looks like
wulffshape.show(color_set="RdBu", direction=(1.00, 0.60, 0.25), output="Two_Species.png")
# Out:
# shape factor: 5.475, anisotropy: 0.100, weighted surface energy: 0.442 J/m^2
