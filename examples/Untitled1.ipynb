# %%
from surfinpy import mu_vs_mu

# %%
bulk = {'Cation' : 1, 'Anion' : 1, 'Energy' : -219.61, 'F-Units' : 6}

# %%
pure =          {'Cation': 10, 'X': 10, 'Y': 0, 'Area': 41.1994, 'Energy': -363.98803,   'Label': 'Dry_pure',  'nSpecies': 1}
H2O_2 =         {'Cation': 10, 'X': 10, 'Y': 4, 'Area': 41.1994, 'Energy': -423.79322,   'Label': '1 Water ', 'nSpecies': 1}
H2O_4 =         {'Cation': 10, 'X': 10, 'Y': 8, 'Area': 41.1994, 'Energy': -481.69872,   'Label': '2 Water', 'nSpecies': 1}
H2O_6 =         {'Cation': 10, 'X': 10, 'Y': 12, 'Area': 41.1994, 'Energy': -541.64924,  'Label': '3 Water', 'nSpecies': 1}

H2O_1_Vo_1 =    {'Cation': 10, 'X': 8, 'Y': 2, 'Area': 41.1994, 'Energy': -346.60909,   'Label': '1 Water 1 Vo', 'nSpecies': 1}
H2O_2_Vo_2 =    {'Cation': 10, 'X': 6, 'Y': 4, 'Area': 41.1994, 'Energy': -329.28619,  'Label': '2 Water 2 Vo', 'nSpecies': 1}

H2O_3_Vo_1 =    {'Cation': 10, 'X': 8, 'Y': 6, 'Area': 41.1994, 'Energy':  -405.61716,  'Label': '3 Water 1 Vo', 'nSpecies': 1}
H2O_4_Vo_2 =    {'Cation': 10, 'X': 6, 'Y': 8, 'Area': 41.1994, 'Energy': -387.25000, 'Label': '4 Water 2 Vo', 'nSpecies': 1}

CatVo_1_H2O_1=  {'Cation': 8, 'X': 10, 'Y': 2, 'Area': 41.1994, 'Energy':  -364.03108, 'Label': '1 Water 1 Ca Vo', 'nSpecies': 1}
CatVo_2_H2O_2 = {'Cation': 6, 'X': 10, 'Y': 4, 'Area': 41.1994, 'Energy': -365.47702, 'Label': '2 Water 2 Ca Vo', 'nSpecies': 1}

CatVo_1_H2O_4 = {'Cation': 8, 'X': 10, 'Y': 6, 'Area': 41.1994, 'Energy': -423.59440 , 'Label': '3 Water 1 Ca Vo', 'nSpecies': 1}
CatVo_2_H2O_2 = {'Cation': 6, 'X': 10, 'Y': 8, 'Area': 41.1994, 'Energy': -425.21718, 'Label': '4 Water 2 Ca Vo', 'nSpecies': 1}

data = [pure, H2O_2, H2O_4, H2O_6, H2O_1_Vo_1, H2O_2_Vo_2, H2O_3_Vo_1, H2O_4_Vo_2, CatVo_1_H2O_1, CatVo_2_H2O_2, CatVo_1_H2O_4, CatVo_2_H2O_2]

# %%
deltaX = {'Range': [ -25, -20], 'Label': 'CO_2'}
deltaY = {'Range': [ -18, -13], 'Label': 'H_2O'}

# %%
system = mu_vs_mu.calculate(data, bulk, deltaX, deltaY, x_energy=-21.28, y_energy=-13.98)
system.plot_phase(output="Example_fast", set_style="fast", colourmap="RdBu", temperature=298)

# %%
system.plot_mu_p(output="Example_ggrd", colourmap="RdYlGn", temperature=298)
# Out:
# /home/adam/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:2299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
system.plot_pressure(output="Example_dark_rdgn", set_style="dark_background", colourmap="PuBu", temperature=298)
